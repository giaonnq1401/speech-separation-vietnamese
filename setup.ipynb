# %%
apt-get update
apt-get install -y curl git-core

mkdir -p ~/.ssh && chmod 700 ~/.ssh

cat > ~/.ssh/id_rsa <<- EOM
-----BEGIN OPENSSH PRIVATE KEY-----

-----END OPENSSH PRIVATE KEY-----

EOM
chmod 400 ~/.ssh/id_rsa

ssh-keygen -F github.com || ssh-keyscan github.com >>~/.ssh/known_hosts

git config --global user.email giaonguyen142001@gmail.com
git config --global user.name giaonnq1401

git clone git@github.com:giaonnq1401/speech-separation-vietnamese.git

cd speech-separation-vietnamese

git pull

pip3 install -r requirements.txt
pip install --editable .

# %%
sudo apt install -y build-essential

# %%
git checkout feat/pretrain-librimix

# %%
cd /workspace/speech-separation-vietnamese

# %%
make create-librimix
